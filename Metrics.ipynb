# %%
# Import required packages 
import json
import requests
import pandas as pd
import urllib
import time
from google.colab import files
import io

# %%
# Define URL  
url = 'https://www.google.com'

# API request url
result = urllib.request.urlopen('https://www.googleapis.com/pagespeedonline/v5/runPagespeed?url={}/&strategy=mobile'\
.format(url)).read().decode('UTF-8')

print(result)
# Out:
# {
#   "captchaResult": "CAPTCHA_NOT_NEEDED",
#   "kind": "pagespeedonline#result",
#   "id": "https://www.google.com/",
#   "loadingExperience": {
#     "id": "https://www.google.com/",
#     "metrics": {
#       "FIRST_CONTENTFUL_PAINT_MS": {
#         "percentile": 1257,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 1000,
#             "proportion": 0.65270386312821782
#           },
#           {
#             "min": 1000,
#             "max": 3000,
#             "proportion": 0.29266783509703564
#           },
#           {
#             "min": 3000,
#             "proportion": 0.054628301774746688
#           }
#         ],
#         "category": "AVERAGE"
#       },
#       "FIRST_INPUT_DELAY_MS": {
#         "percentile": 39,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 100,
#             "proportion": 0.84957976585329531
#           },
#           {
#             "min": 100,
#             "max": 300,
#             "proportion": 0.1031254698538161
#           },
#           {
#             "min": 300,
#             "proportion": 0.047294764292888689
#           }
#         ],
#         "category": "FAST"
#       },
#       "CUMULATIVE_LAYOUT_SHIFT_SCORE": {
#         "percentile": 0,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 10,
#             "proportion": 0.91293719377674953
#           },
#           {
#             "min": 10,
#             "max": 25,
#             "proportion": 0.048416621101648509
#           },
#           {
#             "min": 25,
#             "proportion": 0.038646185121601936
#           }
#         ],
#         "category": "FAST"
#       },
#       "LARGEST_CONTENTFUL_PAINT_MS": {
#         "percentile": 1695,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 2500,
#             "proportion": 0.86912683363139331
#           },
#           {
#             "min": 2500,
#             "max": 4000,
#             "proportion": 0.0804703054420773
#           },
#           {
#             "min": 4000,
#             "proportion": 0.050402860926529555
#           }
#         ],
#         "category": "FAST"
#       }
#     },
#     "overall_category": "AVERAGE",
#     "initial_url": "https://www.google.com/"
#   },
#   "originLoadingExperience": {
#     "id": "https://www.google.com",
#     "metrics": {
#       "FIRST_CONTENTFUL_PAINT_MS": {
#         "percentile": 979,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 1000,
#             "proportion": 0.7566061877487732
#           },
#           {
#             "min": 1000,
#             "max": 3000,
#             "proportion": 0.20201268177209347
#           },
#           {
#             "min": 3000,
#             "proportion": 0.041381130479133173
#           }
#         ],
#         "category": "FAST"
#       },
#       "FIRST_INPUT_DELAY_MS": {
#         "percentile": 30,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 100,
#             "proportion": 0.8710677819696514
#           },
#           {
#             "min": 100,
#             "max": 300,
#             "proportion": 0.074398812913274159
#           },
#           {
#             "min": 300,
#             "proportion": 0.054533405117074406
#           }
#         ],
#         "category": "FAST"
#       },
#       "CUMULATIVE_LAYOUT_SHIFT_SCORE": {
#         "percentile": 0,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 10,
#             "proportion": 0.93578174872691489
#           },
#           {
#             "min": 10,
#             "max": 25,
#             "proportion": 0.027219315029202006
#           },
#           {
#             "min": 25,
#             "proportion": 0.036998936243882889
#           }
#         ],
#         "category": "FAST"
#       },
#       "LARGEST_CONTENTFUL_PAINT_MS": {
#         "percentile": 1467,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 2500,
#             "proportion": 0.89625221958593493
#           },
#           {
#             "min": 2500,
#             "max": 4000,
#             "proportion": 0.056396840932359631
#           },
#           {
#             "min": 4000,
#             "proportion": 0.047350939481705559
#           }
#         ],
#         "category": "FAST"
#       }
#     },
#     "overall_category": "FAST",
#     "initial_url": "https://www.google.com/"
#   },
#   "lighthouseResult": {
#     "requestedUrl": "https://www.google.com/",
#     "finalUrl": "https://www.google.com/",
#     "lighthouseVersion": "6.3.0",
#     "userAgent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/84.0.4147.140 Safari/537.36",
#     "fetchTime": "2020-11-05T14:49:38.839Z",
#     "environment": {
#       "networkUserAgent": "Mozilla/5.0 (Linux; Android 7.0; Moto G (4)) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4143.7 Mobile Safari/537.36 Chrome-Lighthouse",
#       "hostUserAgent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/84.0.4147.140 Safari/537.36",
#       "benchmarkIndex": 1168.5
#     },
#     "runWarnings": [],
#     "configSettings": {
#       "emulatedFormFactor": "mobile",
#       "locale": "en-US",
#       "onlyCategories": [
#         "performance"
#       ],
#       "channel": "lr"
#     },
#     "audits": {
#       "bootup-time": {
#         "id": "bootup-time",
#         "title": "JavaScript execution time",
#         "description": "Consider reducing the time spent parsing, compiling, and executing JS. You may find delivering smaller JS payloads helps with this. [Learn more](https://web.dev/bootup-time/).",
#         "score": 0.95,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "1.0 s",
#         "details": {
#           "summary": {
#             "wastedMs": 959.57600000000059
#           },
#           "items": [
#             {
#               "scriptParseCompile": 66.772,
#               "scripting": 419.5840000000004,
#               "url": "https://www.google.com/xjs/_/js/k=xjs.qs.en_US.e0Xz-1BSey0.O/ck=xjs.qs.wr2XkJ_uShU.L.W.O/m=bct,cdos,hsm,jsa,mpf,pfd,qim,d,csi/am=AAAAAADAAAAAAwAAAGDR6K8zYjkoAgAvbeIAAAAAwANwWNBfgArgAUAABAAAIBSsCQAQAAAQ/d=1/dg=2/br=1/ct=zgms/rs=ACT90oFIGPurHuTHVBGuKCEX359jiN97Wg",
#               "total": 506.56800000000044
#             },
#             {
#               "scripting": 134.6080000000002,
#               "total": 416.16400000000016,
#               "scriptParseCompile": 29.168,
#               "url": "https://www.google.com/"
#             },
#             {
#               "scriptParseCompile": 0.628,
#               "scripting": 5.6879999999999988,
#               "total": 172.90399999999991,
#               "url": "Unattributable"
#             },
#             {
#               "scripting": 114.44000000000001,
#               "total": 138.76400000000004,
#               "scriptParseCompile": 19.416,
#               "url": "https://www.google.com/xjs/_/js/k=xjs.qs.en_US.e0Xz-1BSey0.O/ck=xjs.qs.wr2XkJ_uShU.L.W.O/am=AAAAAADAAAAAAwAAAGDR6K8zYjkoAgAvbeIAAAAAwANwWNBfgArgAUAABAAAIBSsCQAQAAAQ/d=1/exm=bct,cdos,csi,d,hsm,jsa,mpf,pfd,qim/ed=1/dg=2/br=1/ct=zgms/rs=ACT90oFIGPurHuTHVBGuKCEX359jiN97Wg/m=aa,abd,async,dvl,fEVMic,foot,mUpTid,mu,rQSi2,sb_wiz,sf,sonic,spch,xz7cCd?xjs=s1"
#             },
#             {
#               "total": 121.54000000000002,
#               "scriptParseCompile": 13.256,
#               "url": "https://www.gstatic.com/og/_/js/k=og.qtm.en_US.cifjL1QQe00.O/rt=j/m=qabr,q_d,qcwid,qmutsd,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTspWxp-F7byA8PpAfjxHzqcwSVeVA",
#               "scripting": 103.38400000000001
#             },
#             {
#               "scriptParseCompile": 5.7479999999999993,
#               "scripting": 46.884,
#               "url": "https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.40L1XIQnUK4.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo87VqKnhJy5DXHDJekiAyngLi-Q2w/cb=gapi.loaded_0",
#               "total": 55.524
#             }
#           ],
#           "headings": [
#             {
#               "text": "URL",
#               "itemType": "url",
#               "key": "url"
#             },
#             {
#               "itemType": "ms",
#               "key": "total",
#               "text": "Total CPU Time",
#               "granularity": 1
#             },
#             {
#               "granularity": 1,
#               "itemType": "ms",
#               "key": "scripting",
#               "text": "Script Evaluation"
#             },
#             {
#               "granularity": 1,
#               "text": "Script Parse",
#               "key": "scriptParseCompile",
#               "itemType": "ms"
#             }
#           ],
#           "type": "table"
#         },
#         "numericValue": 959.57600000000059
#       },
#       "duplicated-javascript": {
#         "id": "duplicated-javascript",
#         "title": "Remove duplicate modules in JavaScript bundles",
#         "description": "Remove large, duplicate JavaScript modules from bundles to reduce unnecessary bytes consumed by network activity. ",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "type": "opportunity",
#           "overallSavingsMs": 0,
#           "overallSavingsBytes": 0,
#           "headings": [],
#           "items": []
#         },
#         "numericValue": 0
#       },
#       "main-thread-tasks": {
#         "id": "main-thread-tasks",
#         "title": "Tasks",
#         "description": "Lists the toplevel main thread tasks that executed during page load.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "type": "table",
#           "items": [
#             {
#               "duration": 8.565,
#               "startTime": 118.598
#             },
#             {
#               "duration": 17.566,
#               "startTime": 129.587
#             },
#             {
#               "duration": 9.258,
#               "startTime": 153.276
#             },
#             {
#               "startTime": 168.747,
#               "duration": 44.343
#             },
#             {
#               "startTime": 233.378,
#               "duration": 30.413
#             },
#             {
#               "startTime": 272.018,
#               "duration": 13.91
#             },
#             {
#               "startTime": 309.642,
#               "duration": 81.686
#             },
#             {
#               "duration": 9.297,
#               "startTime": 392.774
#             },
#             {
#               "startTime": 402.08,
#               "duration": 40.501
#             },
#             {
#               "duration": 6.666,
#               "startTime": 443.446
#             },
#             {
#               "startTime": 472.401,
#               "duration": 34.781
#             }
#           ],
#           "headings": [
#             {
#               "granularity": 1,
#               "key": "startTime",
#               "itemType": "ms",
#               "text": "Start Time"
#             },
#             {
#               "granularity": 1,
#               "itemType": "ms",
#               "text": "End Time",
#               "key": "duration"
#             }
#           ]
#         }
#       },
#       "critical-request-chains": {
#         "id": "critical-request-chains",
#         "title": "Avoid chaining critical requests",
#         "description": "The Critical Request Chains below show you what resources are loaded with a high priority. Consider reducing the length of chains, reducing the download size of resources, or deferring the download of unnecessary resources to improve page load. [Learn more](https://web.dev/critical-request-chains/).",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "displayValue": "1 chain found",
#         "details": {
#           "chains": {
#             "D44A6E067AD8964EB689FCB3BCDFC2BC": {
#               "request": {
#                 "transferSize": 39934,
#                 "startTime": 189401.286738,
#                 "responseReceivedTime": 189401.373455,
#                 "endTime": 189401.373457,
#                 "url": "https://www.google.com/"
#               },
#               "children": {
#                 "24.6": {
#                   "request": {
#                     "endTime": 189401.466322,
#                     "responseReceivedTime": 189401.46632,
#                     "url": "https://www.gstatic.com/og/_/ss/k=og.qtm.b3g6mLNCyqI.L.W.O/m=qcwid/excm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/ct=zgms/rs=AA2YrTvjzodeDhDPYO5LKZroaMuA8P2I-Q",
#                     "transferSize": 833,
#                     "startTime": 189401.463224
#                   }
#                 }
#               }
#             }
#           },
#           "type": "criticalrequestchain",
#           "longestChain": {
#             "duration": 179.58399999770336,
#             "transferSize": 833,
#             "length": 2
#           }
#         }
#       },
#       "cumulative-layout-shift": {
#         "id": "cumulative-layout-shift",
#         "title": "Cumulative Layout Shift",
#         "description": "Cumulative Layout Shift measures the movement of visible elements within the viewport. [Learn more](https://web.dev/cls/).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "0",
#         "details": {
#           "type": "debugdata",
#           "items": [
#             {
#               "finalLayoutShiftTraceEventFound": false
#             }
#           ]
#         },
#         "numericValue": 0
#       },
#       "third-party-summary": {
#         "id": "third-party-summary",
#         "title": "Minimize third-party usage",
#         "description": "Third-party code can significantly impact load performance. Limit the number of redundant third-party providers and try to load third-party code after your page has primarily finished loading. [Learn more](https://developers.google.com/web/fundamentals/performance/optimizing-content-efficiency/loading-third-party-javascript/).",
#         "score": 1,
#         "scoreDisplayMode": "binary",
#         "displayValue": "Third-party code blocked the main thread for 50 ms",
#         "details": {
#           "items": [
#             {
#               "entity": {
#                 "text": "Google CDN",
#                 "url": "https://developers.google.com/speed/libraries/",
#                 "type": "link"
#               },
#               "subItems": {
#                 "type": "subitems",
#                 "items": [
#                   {
#                     "mainThreadTime": 121.54000000000002,
#                     "url": "https://www.gstatic.com/og/_/js/k=og.qtm.en_US.cifjL1QQe00.O/rt=j/m=qabr,q_d,qcwid,qmutsd,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTspWxp-F7byA8PpAfjxHzqcwSVeVA",
#                     "transferSize": 59392,
#                     "blockingTime": 50.732
#                   },
#                   {
#                     "transferSize": 10023,
#                     "blockingTime": 0,
#                     "url": "Other resources"
#                   }
#                 ]
#               },
#               "mainThreadTime": 123.54800000000002,
#               "transferSize": 69415,
#               "blockingTime": 50.732
#             },
#             {
#               "mainThreadTime": 0,
#               "transferSize": 945,
#               "blockingTime": 0,
#               "entity": {
#                 "type": "link",
#                 "text": "Google/Doubleclick Ads",
#                 "url": "https://www.doubleclickbygoogle.com/"
#               },
#               "subItems": {
#                 "items": [],
#                 "type": "subitems"
#               }
#             }
#           ],
#           "summary": {
#             "wastedBytes": 70360,
#             "wastedMs": 50.732
#           },
#           "headings": [
#             {
#               "itemType": "link",
#               "key": "entity",
#               "text": "Third-Party",
#               "subItemsHeading": {
#                 "itemType": "url",
#                 "key": "url"
#               }
#             },
#             {
#               "text": "Transfer Size",
#               "granularity": 1,
#               "subItemsHeading": {
#                 "key": "transferSize"
#               },
#               "itemType": "bytes",
#               "key": "transferSize"
#             },
#             {
#               "itemType": "ms",
#               "key": "blockingTime",
#               "text": "Main-Thread Blocking Time",
#               "granularity": 1,
#               "subItemsHeading": {
#                 "key": "blockingTime"
#               }
#             }
#           ],
#           "type": "table"
#         }
#       },
#       "interactive": {
#         "id": "interactive",
#         "title": "Time to Interactive",
#         "description": "Time to interactive is the amount of time it takes for the page to become fully interactive. [Learn more](https://web.dev/interactive/).",
#         "score": 0.8,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "4.7 s",
#         "numericValue": 4699
#       },
#       "estimated-input-latency": {
#         "id": "estimated-input-latency",
#         "title": "Estimated Input Latency",
#         "description": "Estimated Input Latency is an estimate of how long your app takes to respond to user input, in milliseconds, during the busiest 5s window of page load. If your latency is higher than 50 ms, users may perceive your app as laggy. [Learn more](https://web.dev/estimated-input-latency/).",
#         "score": 0.85,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "60 ms",
#         "numericValue": 64.92
#       },
#       "large-javascript-libraries": {
#         "id": "large-javascript-libraries",
#         "title": "Avoids large JavaScript libraries with smaller alternatives",
#         "description": "Large JavaScript libraries can lead to poor performance. Prefer smaller, functionally equivalent libraries to reduce your bundle size. [Learn more](https://developers.google.com/web/fundamentals/performance/webpack/decrease-frontend-size#optimize_dependencies).",
#         "score": 1,
#         "scoreDisplayMode": "binary",
#         "displayValue": "0 large libraries found",
#         "details": {
#           "summary": {},
#           "headings": [],
#           "type": "table",
#           "items": []
#         }
#       },
#       "mainthread-work-breakdown": {
#         "id": "mainthread-work-breakdown",
#         "title": "Minimizes main-thread work",
#         "description": "Consider reducing the time spent parsing, compiling and executing JS. You may find delivering smaller JS payloads helps with this. [Learn more](https://web.dev/mainthread-work-breakdown/)",
#         "score": 0.97,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "1.4 s",
#         "details": {
#           "type": "table",
#           "headings": [
#             {
#               "key": "groupLabel",
#               "text": "Category",
#               "itemType": "text"
#             },
#             {
#               "key": "duration",
#               "granularity": 1,
#               "text": "Time Spent",
#               "itemType": "ms"
#             }
#           ],
#           "items": [
#             {
#               "duration": 828.228,
#               "group": "scriptEvaluation",
#               "groupLabel": "Script Evaluation"
#             },
#             {
#               "groupLabel": "Other",
#               "duration": 197.01200000000082,
#               "group": "other"
#             },
#             {
#               "groupLabel": "Style & Layout",
#               "group": "styleLayout",
#               "duration": 145.29999999999998
#             },
#             {
#               "duration": 136,
#               "group": "scriptParseCompile",
#               "groupLabel": "Script Parsing & Compilation"
#             },
#             {
#               "groupLabel": "Parse HTML & CSS",
#               "duration": 68.424000000000035,
#               "group": "parseHTML"
#             },
#             {
#               "duration": 26.567999999999991,
#               "group": "garbageCollection",
#               "groupLabel": "Garbage Collection"
#             },
#             {
#               "group": "paintCompositeRender",
#               "duration": 17.148000000000003,
#               "groupLabel": "Rendering"
#             }
#           ]
#         },
#         "numericValue": 1418.6800000000005
#       },
#       "performance-budget": {
#         "id": "performance-budget",
#         "title": "Performance budget",
#         "description": "Keep the quantity and size of network requests under the targets set by the provided performance budget. [Learn more](https://developers.google.com/web/tools/lighthouse/audits/budgets).",
#         "score": null,
#         "scoreDisplayMode": "notApplicable"
#       },
#       "unused-javascript": {
#         "id": "unused-javascript",
#         "title": "Remove unused JavaScript",
#         "description": "Remove unused JavaScript to reduce bytes consumed by network activity. [Learn more](https://web.dev/unused-javascript/).",
#         "score": 0.43,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "Potential savings of 183 KiB",
#         "details": {
#           "overallSavingsBytes": 187327,
#           "type": "opportunity",
#           "headings": [
#             {
#               "subItemsHeading": {
#                 "key": "source",
#                 "valueType": "code"
#               },
#               "key": "url",
#               "valueType": "url",
#               "label": "URL"
#             },
#             {
#               "subItemsHeading": {
#                 "key": "sourceBytes"
#               },
#               "valueType": "bytes",
#               "label": "Transfer Size",
#               "key": "totalBytes"
#             },
#             {
#               "subItemsHeading": {
#                 "key": "sourceWastedBytes"
#               },
#               "label": "Potential Savings",
#               "key": "wastedBytes",
#               "valueType": "bytes"
#             }
#           ],
#           "overallSavingsMs": 1350,
#           "items": [
#             {
#               "url": "https://www.google.com/xjs/_/js/k=xjs.qs.en_US.e0Xz-1BSey0.O/ck=xjs.qs.wr2XkJ_uShU.L.W.O/m=bct,cdos,hsm,jsa,mpf,pfd,qim,d,csi/am=AAAAAADAAAAAAwAAAGDR6K8zYjkoAgAvbeIAAAAAwANwWNBfgArgAUAABAAAIBSsCQAQAAAQ/d=1/dg=2/br=1/ct=zgms/rs=ACT90oFIGPurHuTHVBGuKCEX359jiN97Wg",
#               "totalBytes": 205871,
#               "wastedBytes": 90460,
#               "wastedPercent": 43.940094060997588
#             },
#             {
#               "wastedPercent": 66.0955779129621,
#               "totalBytes": 59392,
#               "url": "https://www.gstatic.com/og/_/js/k=og.qtm.en_US.cifjL1QQe00.O/rt=j/m=qabr,q_d,qcwid,qmutsd,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTspWxp-F7byA8PpAfjxHzqcwSVeVA",
#               "wastedBytes": 39255
#             },
#             {
#               "wastedBytes": 35634,
#               "wastedPercent": 66.635594643260362,
#               "totalBytes": 53476,
#               "url": "https://www.google.com/xjs/_/js/k=xjs.qs.en_US.e0Xz-1BSey0.O/ck=xjs.qs.wr2XkJ_uShU.L.W.O/am=AAAAAADAAAAAAwAAAGDR6K8zYjkoAgAvbeIAAAAAwANwWNBfgArgAUAABAAAIBSsCQAQAAAQ/d=1/exm=bct,cdos,csi,d,hsm,jsa,mpf,pfd,qim/ed=1/dg=2/br=1/ct=zgms/rs=ACT90oFIGPurHuTHVBGuKCEX359jiN97Wg/m=aa,abd,async,dvl,fEVMic,foot,mUpTid,mu,rQSi2,sb_wiz,sf,sonic,spch,xz7cCd?xjs=s1"
#             },
#             {
#               "wastedPercent": 62.50261435955661,
#               "wastedBytes": 21978,
#               "totalBytes": 35163,
#               "url": "https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.40L1XIQnUK4.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo87VqKnhJy5DXHDJekiAyngLi-Q2w/cb=gapi.loaded_0"
#             }
#           ]
#         },
#         "numericValue": 1350
#       },
#       "screenshot-thumbnails": {
#         "id": "screenshot-thumbnails",
#         "title": "Screenshot Thumbnails",
#         "description": "This is what the load of your site looked like.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "scale": 3000,
#           "type": "filmstrip",
#           "items": [
#             {
#               "timestamp": 189401585558,
#               "data": "data:image/jpeg;base64,...",
#               "timing": 300
#             },
#             {
#               "data": "data:image/jpeg;base64,...",
#               "timing": 600,
#               "timestamp": 189401885558
#             },
#             {
#               "data": "data:image/jpeg;base64,...",
#               "timestamp": 189402185558,
#               "timing": 900
#             },
#             {
#               "timing": 1200,
#               "data": "data:image/jpeg;base64,...",
#               "timestamp": 189402485558
#             },
#             {
#               "data": "data:image/jpeg;base64,...",
#               "timestamp": 189402785558,
#               "timing": 1500
#             },
#             {
#               "timestamp": 189403085558,
#               "timing": 1800,
#               "data": "data:image/jpeg;base64,..."
#             },
#             {
#               "data": "data:image/jpeg;base64,...",
#               "timing": 2100,
#               "timestamp": 189403385558
#             },
#             {
#               "data": "data:image/jpeg;base64,...",
#               "timestamp": 189403685558,
#               "timing": 2400
#             },
#             {
#               "timestamp": 189403985558,
#               "data": "data:image/jpeg;base64,...",
#               "timing": 2700
#             },
#             {
#               "data": "data:image/jpeg;base64,...",
#               "timing": 3000,
#               "timestamp": 189404285558
#             }
#           ]
#         }
#       },
#       "largest-contentful-paint-element": {
#         "id": "largest-contentful-paint-element",
#         "title": "Largest Contentful Paint element",
#         "description": "This is the largest contentful element painted within the viewport. [Learn More](https://web.dev/lighthouse-largest-contentful-paint/)",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "displayValue": "1 element found",
#         "details": {
#           "items": [
#             {
#               "node": {
#                 "snippet": "\u003cimg style=\"border:none;margin:8px 0\" height=\"56\" src=\"/images/branding/googlelogo/2x/googlelogo_color_160x56dp.png\" width=\"160\" id=\"hplogo\" alt=\"Google\" data-atf=\"1\"\u003e",
#                 "boundingRect": {
#                   "top": 112,
#                   "left": 100,
#                   "width": 160,
#                   "height": 56,
#                   "bottom": 168,
#                   "right": 260
#                 },
#                 "nodeLabel": "Google",
#                 "type": "node",
#                 "path": "1,HTML,1,BODY,3,DIV,2,DIV,0,DIV,0,IMG",
#                 "selector": "div#gb-main \u003e div#outer \u003e div#hplogoo \u003e img#hplogo"
#               }
#             }
#           ],
#           "type": "table",
#           "headings": [
#             {
#               "itemType": "node",
#               "key": "node",
#               "text": "Element"
#             }
#           ]
#         }
#       },
#       "network-server-latency": {
#         "id": "network-server-latency",
#         "title": "Server Backend Latencies",
#         "description": "Server latencies can impact web performance. If the server latency of an origin is high, it's an indication the server is overloaded or has poor backend performance. [Learn more](https://hpbn.co/primer-on-web-performance/#analyzing-the-resource-waterfall).",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "displayValue": "0 ms",
#         "details": {
#           "headings": [],
#           "type": "table",
#           "items": []
#         },
#         "numericValue": 0
#       },
#       "non-composited-animations": {
#         "id": "non-composited-animations",
#         "title": "Avoid non-composited animations",
#         "description": "Animations which are not composited can be janky and increase CLS. [Learn more](https://web.dev/non-composited-animations)",
#         "score": null,
#         "scoreDisplayMode": "notApplicable"
#       },
#       "unminified-css": {
#         "id": "unminified-css",
#         "title": "Minify CSS",
#         "description": "Minifying CSS files can reduce network payload sizes. [Learn more](https://web.dev/unminified-css/).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "type": "opportunity",
#           "items": [],
#           "overallSavingsBytes": 0,
#           "headings": [],
#           "overallSavingsMs": 0
#         },
#         "numericValue": 0
#       },
#       "dom-size": {
#         "id": "dom-size",
#         "title": "Avoids an excessive DOM size",
#         "description": "A large DOM will increase memory usage, cause longer [style calculations](https://developers.google.com/web/fundamentals/performance/rendering/reduce-the-scope-and-complexity-of-style-calculations), and produce costly [layout reflows](https://developers.google.com/speed/articles/reflow). [Learn more](https://web.dev/dom-size/).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "228 elements",
#         "details": {
#           "type": "table",
#           "items": [
#             {
#               "value": "228",
#               "statistic": "Total DOM Elements"
#             },
#             {
#               "statistic": "Maximum DOM Depth",
#               "element": {
#                 "type": "code",
#                 "value": "\u003cstyle data-iml=\"1604587780069\"\u003e"
#               },
#               "value": "17"
#             },
#             {
#               "value": "16",
#               "statistic": "Maximum Child Elements",
#               "element": {
#                 "type": "code",
#                 "value": "\u003cbody jsmodel=\"TvHxbe\"\u003e"
#               }
#             }
#           ],
#           "headings": [
#             {
#               "itemType": "text",
#               "text": "Statistic",
#               "key": "statistic"
#             },
#             {
#               "itemType": "code",
#               "key": "element",
#               "text": "Element"
#             },
#             {
#               "text": "Value",
#               "key": "value",
#               "itemType": "numeric"
#             }
#           ]
#         },
#         "numericValue": 228
#       },
#       "uses-rel-preload": {
#         "id": "uses-rel-preload",
#         "title": "Preload key requests",
#         "description": "Consider using `\u003clink rel=preload\u003e` to prioritize fetching resources that are currently requested later in page load. [Learn more](https://web.dev/uses-rel-preload/).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "overallSavingsMs": 0,
#           "headings": [],
#           "items": [],
#           "type": "opportunity"
#         },
#         "numericValue": 0
#       },
#       "diagnostics": {
#         "id": "diagnostics",
#         "title": "Diagnostics",
#         "description": "Collection of useful page vitals.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "type": "debugdata",
#           "items": [
#             {
#               "totalTaskTime": 354.669999999999,
#               "throughput": 94599010096.6921,
#               "numTasks": 462,
#               "numTasksOver500ms": 0,
#               "numTasksOver25ms": 5,
#               "maxRtt": 0.00029259391929416549,
#               "numTasksOver50ms": 1,
#               "rtt": 0.00029259391929416549,
#               "numFonts": 0,
#               "numRequests": 25,
#               "numTasksOver100ms": 0,
#               "totalByteWeight": 437521,
#               "maxServerLatency": null,
#               "numTasksOver10ms": 7,
#               "mainDocumentTransferSize": 39934,
#               "numStylesheets": 1,
#               "numScripts": 5
#             }
#           ]
#         }
#       },
#       "timing-budget": {
#         "id": "timing-budget",
#         "title": "Timing budget",
#         "description": "Set a timing budget to help you keep an eye on the performance of your site. Performant sites load fast and respond to user input events quickly. [Learn more](https://developers.google.com/web/tools/lighthouse/audits/budgets).",
#         "score": null,
#         "scoreDisplayMode": "notApplicable"
#       },
#       "largest-contentful-paint": {
#         "id": "largest-contentful-paint",
#         "title": "Largest Contentful Paint",
#         "description": "Largest Contentful Paint marks the time at which the largest text or image is painted. [Learn More](https://web.dev/lighthouse-largest-contentful-paint/)",
#         "score": 0.99,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "1.7 s",
#         "numericValue": 1710
#       },
#       "user-timings": {
#         "id": "user-timings",
#         "title": "User Timing marks and measures",
#         "description": "Consider instrumenting your app with the User Timing API to measure your app's real-world performance during key user experiences. [Learn more](https://web.dev/user-timings/).",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "displayValue": "2 user timings",
#         "details": {
#           "headings": [
#             {
#               "text": "Name",
#               "itemType": "text",
#               "key": "name"
#             },
#             {
#               "key": "timingType",
#               "itemType": "text",
#               "text": "Type"
#             },
#             {
#               "text": "Start Time",
#               "key": "startTime",
#               "granularity": 0.01,
#               "itemType": "ms"
#             },
#             {
#               "text": "Duration",
#               "key": "duration",
#               "granularity": 0.01,
#               "itemType": "ms"
#             }
#           ],
#           "type": "table",
#           "items": [
#             {
#               "startTime": 376.625,
#               "duration": 19.21,
#               "timingType": "Measure",
#               "name": "kDcP9b"
#             },
#             {
#               "startTime": 376.649,
#               "timingType": "Mark",
#               "name": "O7jPNb"
#             }
#           ]
#         }
#       },
#       "server-response-time": {
#         "id": "server-response-time",
#         "title": "Initial server response time was short",
#         "description": "Keep the server response time for the main document short because all other requests depend on it. [Learn more](https://web.dev/time-to-first-byte/).",
#         "score": 1,
#         "scoreDisplayMode": "binary",
#         "displayValue": "Root document took 90 ms",
#         "details": {
#           "items": [
#             {
#               "url": "https://www.google.com/",
#               "responseTime": 87.717
#             }
#           ],
#           "overallSavingsMs": -12.283000000000001,
#           "headings": [
#             {
#               "valueType": "url",
#               "label": "URL",
#               "key": "url"
#             },
#             {
#               "label": "Time Spent",
#               "key": "responseTime",
#               "valueType": "timespanMs"
#             }
#           ],
#           "type": "opportunity"
#         },
#         "numericValue": 87.717
#       },
#       "unused-css-rules": {
#         "id": "unused-css-rules",
#         "title": "Remove unused CSS",
#         "description": "Remove dead rules from stylesheets and defer the loading of CSS not used for above-the-fold content to reduce unnecessary bytes consumed by network activity. [Learn more](https://web.dev/unused-css-rules/).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "type": "opportunity",
#           "headings": [],
#           "overallSavingsMs": 0,
#           "overallSavingsBytes": 0,
#           "items": []
#         },
#         "numericValue": 0
#       },
#       "network-requests": {
#         "id": "network-requests",
#         "title": "Network Requests",
#         "description": "Lists the network requests that were made during page load.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "headings": [
#             {
#               "key": "url",
#               "text": "URL",
#               "itemType": "url"
#             },
#             {
#               "itemType": "ms",
#               "text": "Start Time",
#               "key": "startTime",
#               "granularity": 1
#             },
#             {
#               "granularity": 1,
#               "itemType": "ms",
#               "key": "endTime",
#               "text": "End Time"
#             },
#             {
#               "displayUnit": "kb",
#               "granularity": 1,
#               "text": "Transfer Size",
#               "itemType": "bytes",
#               "key": "transferSize"
#             },
#             {
#               "granularity": 1,
#               "displayUnit": "kb",
#               "key": "resourceSize",
#               "itemType": "bytes",
#               "text": "Resource Size"
#             },
#             {
#               "text": "Status Code",
#               "itemType": "text",
#               "key": "statusCode"
#             },
#             {
#               "key": "mimeType",
#               "itemType": "text",
#               "text": "MIME Type"
#             },
#             {
#               "key": "resourceType",
#               "text": "Resource Type",
#               "itemType": "text"
#             }
#           ],
#           "items": [
#             {
#               "statusCode": 200,
#               "resourceType": "Document",
#               "url": "https://www.google.com/",
#               "startTime": 0,
#               "mimeType": "text/html",
#               "resourceSize": 131399,
#               "finished": true,
#               "endTime": 86.719000013545156,
#               "transferSize": 39934
#             },
#             {
#               "resourceSize": 7048,
#               "finished": true,
#               "resourceType": "Image",
#               "url": "https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_160x56dp.png",
#               "transferSize": 7574,
#               "statusCode": 200,
#               "endTime": 125.89600001228973,
#               "startTime": 121.34400001377799,
#               "mimeType": "image/png"
#             },
#             {
#               "resourceType": "Image",
#               "resourceSize": 1700,
#               "finished": true,
#               "startTime": 145.27700000326149,
#               "statusCode": 200,
#               "mimeType": "image/webp",
#               "transferSize": 2227,
#               "endTime": 148.47600000211969,
#               "url": "https://www.google.com/images/searchbox/searchbox_sprites317_hr.webp"
#             },
#             {
#               "mimeType": "text/javascript",
#               "transferSize": 59392,
#               "resourceSize": 170960,
#               "url": "https://www.gstatic.com/og/_/js/k=og.qtm.en_US.cifjL1QQe00.O/rt=j/m=qabr,q_d,qcwid,qmutsd,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTspWxp-F7byA8PpAfjxHzqcwSVeVA",
#               "resourceType": "Script",
#               "statusCode": 200,
#               "startTime": 176.11900001065806,
#               "endTime": 184.89500001305714,
#               "finished": true
#             },
#             {
#               "finished": true,
#               "endTime": 179.58399999770336,
#               "resourceType": "Stylesheet",
#               "statusCode": 200,
#               "startTime": 176.4860000112094,
#               "url": "https://www.gstatic.com/og/_/ss/k=og.qtm.b3g6mLNCyqI.L.W.O/m=qcwid/excm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/ct=zgms/rs=AA2YrTvjzodeDhDPYO5LKZroaMuA8P2I-Q",
#               "resourceSize": 296,
#               "transferSize": 833,
#               "mimeType": "text/css"
#             },
#             {
#               "resourceType": "Other",
#               "finished": true,
#               "endTime": 189.29500001831912,
#               "resourceSize": 0,
#               "statusCode": -1,
#               "transferSize": 0,
#               "startTime": 181.40000000130385,
#               "url": "https://www.google.com/gen_204?s=webhp&t=aft&atyp=csi&ei=AxGkX9iWOePRmAXnro3ACw&rt=wsrt.88,aft.91&imn=1&bl=EpvJ&ima=0&imad=0"
#             },
#             {
#               "resourceType": "Image",
#               "statusCode": 200,
#               "endTime": 187.43399999220856,
#               "resourceSize": 4726,
#               "finished": true,
#               "startTime": 183.65099999937229,
#               "transferSize": 5253,
#               "mimeType": "image/webp",
#               "url": "https://www.google.com/images/nav_logo289_hr.webp"
#             },
#             {
#               "url": "https://www.google.com/xjs/_/js/k=xjs.qs.en_US.e0Xz-1BSey0.O/ck=xjs.qs.wr2XkJ_uShU.L.W.O/m=bct,cdos,hsm,jsa,mpf,pfd,qim,d,csi/am=AAAAAADAAAAAAwAAAGDR6K8zYjkoAgAvbeIAAAAAwANwWNBfgArgAUAABAAAIBSsCQAQAAAQ/d=1/dg=2/br=1/ct=zgms/rs=ACT90oFIGPurHuTHVBGuKCEX359jiN97Wg",
#               "transferSize": 205871,
#               "endTime": 207.1120000036899,
#               "finished": true,
#               "statusCode": 200,
#               "resourceSize": 668715,
#               "startTime": 190.67199999699369,
#               "resourceType": "Script",
#               "mimeType": "text/javascript"
#             },
#             {
#               "transferSize": 35163,
#               "startTime": 223.61300000920892,
#               "statusCode": 200,
#               "finished": true,
#               "resourceType": "Script",
#               "endTime": 230.3820000088308,
#               "resourceSize": 100407,
#               "url": "https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.40L1XIQnUK4.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo87VqKnhJy5DXHDJekiAyngLi-Q2w/cb=gapi.loaded_0",
#               "mimeType": "text/javascript"
#             },
#             {
#               "startTime": 231.48499999661,
#               "transferSize": 15884,
#               "resourceType": "Other",
#               "endTime": 320.23199999821372,
#               "finished": true,
#               "mimeType": "text/html",
#               "url": "https://ogs.google.com/widget/app/so?origin=https%3A%2F%2Fwww.google.com&cn=app&pid=1&spid=1&hl=en",
#               "statusCode": 200,
#               "resourceSize": 0
#             },
#             {
#               "statusCode": -1,
#               "resourceType": "Other",
#               "startTime": 372.04000001656823,
#               "url": "https://www.google.com/gen_204?atyp=csi&ei=AxGkX9iWOePRmAXnro3ACw&s=webhp&t=all&bl=EpvJ&imn=1&adh=&conn=onchange&ima=1&imad=0&ime=1&imex=1&imeh=0&imea=0&imeb=0&wh=640&scp=0&net=dl.9500,ect.4g,rtt.0&mem=ujhs.15,tjhs.26,jhsl.3760,dm.8&sto=&sys=hc.88&rt=aft.91,prt.91,iml.91,dcl.95,xjsls.103,xjses.216,xjsee.272,xjs.272,ol.279,wsrt.88,cst.0,dnst.0,rqst.88,rspt.0,rqstt.0,unt.0,cstt.0,dit.183&zx=1604587780302",
#               "resourceSize": 0,
#               "transferSize": 0,
#               "endTime": 414.34000001754612,
#               "finished": true
#             },
#             {
#               "startTime": 407.67700001015328,
#               "finished": true,
#               "endTime": 416.98199999518692,
#               "url": "https://www.google.com/xjs/_/js/k=xjs.qs.en_US.e0Xz-1BSey0.O/ck=xjs.qs.wr2XkJ_uShU.L.W.O/am=AAAAAADAAAAAAwAAAGDR6K8zYjkoAgAvbeIAAAAAwANwWNBfgArgAUAABAAAIBSsCQAQAAAQ/d=1/exm=bct,cdos,csi,d,hsm,jsa,mpf,pfd,qim/ed=1/dg=2/br=1/ct=zgms/rs=ACT90oFIGPurHuTHVBGuKCEX359jiN97Wg/m=aa,abd,async,dvl,fEVMic,foot,mUpTid,mu,rQSi2,sb_wiz,sf,sonic,spch,xz7cCd?xjs=s1",
#               "mimeType": "text/javascript",
#               "transferSize": 53476,
#               "statusCode": 200,
#               "resourceType": "Script",
#               "resourceSize": 172717
#             },
#             {
#               "url": "https://www.google.com/client_204?&atyp=i&biw=360&bih=640&dpr=2.625&mtp=1&ei=AxGkX9iWOePRmAXnro3ACw",
#               "resourceType": "Image",
#               "endTime": 423.42500001541339,
#               "transferSize": 560,
#               "mimeType": "text/html",
#               "startTime": 411.17199999280274,
#               "statusCode": 204,
#               "resourceSize": 0,
#               "finished": true
#             },
#             {
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "transferSize": 767,
#               "url": "https://www.gstatic.com/navigationdrawer/home_icon.svg",
#               "finished": true,
#               "endTime": 417.83900000154972,
#               "startTime": 411.33900001295842,
#               "resourceSize": 232
#             },
#             {
#               "resourceSize": 393,
#               "startTime": 411.50099999504164,
#               "finished": true,
#               "statusCode": 200,
#               "resourceType": "Image",
#               "transferSize": 867,
#               "endTime": 417.58599999593571,
#               "url": "https://www.gstatic.com/navigationdrawer/search_activity_icon.svg",
#               "mimeType": "image/svg+xml"
#             },
#             {
#               "statusCode": 200,
#               "startTime": 411.921999999322,
#               "mimeType": "image/svg+xml",
#               "resourceType": "Image",
#               "resourceSize": 1016,
#               "transferSize": 1135,
#               "finished": true,
#               "url": "https://www.gstatic.com/navigationdrawer/save_icon.svg",
#               "endTime": 418.17799999262206
#             },
#             {
#               "finished": true,
#               "statusCode": 200,
#               "endTime": 418.63699999521486,
#               "startTime": 412.08899999037385,
#               "url": "https://www.gstatic.com/navigationdrawer/manage_searches_icon.png",
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "transferSize": 1009,
#               "resourceSize": 472
#             },
#             {
#               "startTime": 412.46399999363348,
#               "mimeType": "image/svg+xml",
#               "resourceSize": 869,
#               "endTime": 418.44000000855885,
#               "url": "https://www.gstatic.com/navigationdrawer/settings_icon.svg",
#               "transferSize": 1049,
#               "statusCode": 200,
#               "resourceType": "Image",
#               "finished": true
#             },
#             {
#               "transferSize": 997,
#               "endTime": 419.06300000846386,
#               "finished": true,
#               "mimeType": "image/svg+xml",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "startTime": 412.61800000211224,
#               "resourceSize": 796,
#               "url": "https://www.gstatic.com/navigationdrawer/privacy_advisor_icon.svg"
#             },
#             {
#               "mimeType": "image/svg+xml",
#               "startTime": 412.72399999434128,
#               "transferSize": 792,
#               "url": "https://www.gstatic.com/navigationdrawer/explicit_icon.svg",
#               "statusCode": 200,
#               "finished": true,
#               "endTime": 418.86000000522472,
#               "resourceSize": 255,
#               "resourceType": "Image"
#             },
#             {
#               "transferSize": 885,
#               "mimeType": "image/svg+xml",
#               "endTime": 419.35700000612997,
#               "url": "https://www.gstatic.com/navigationdrawer/how_search_works_icon.svg",
#               "finished": true,
#               "statusCode": 200,
#               "resourceType": "Image",
#               "startTime": 413.69300000951625,
#               "resourceSize": 440
#             },
#             {
#               "url": "https://www.gstatic.com/navigationdrawer/help_icon.svg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "resourceSize": 465,
#               "endTime": 420.77100000460632,
#               "finished": true,
#               "startTime": 416.19499999796972,
#               "mimeType": "image/svg+xml",
#               "transferSize": 890
#             },
#             {
#               "statusCode": 200,
#               "transferSize": 799,
#               "endTime": 420.5939999956172,
#               "finished": true,
#               "resourceType": "Image",
#               "url": "https://www.gstatic.com/navigationdrawer/feedback_icon.svg",
#               "mimeType": "image/svg+xml",
#               "startTime": 416.31500000949018,
#               "resourceSize": 273
#             },
#             {
#               "startTime": 458.55199999641627,
# ...
#             {
#               "valueType": "url",
#               "subItemsHeading": {
#                 "key": "location",
#                 "valueType": "source-location"
#               },
#               "key": "url",
#               "label": "URL"
#             },
#             {
#               "valueType": "code",
#               "subItemsHeading": {
#                 "key": "signal"
#               },
#               "key": null
#             },
#             {
#               "label": "Potential Savings",
#               "valueType": "bytes",
#               "key": "wastedBytes"
#             }
#           ],
#           "overallSavingsMs": 0
#         },
#         "numericValue": 0
#       },
#       "metrics": {
#         "id": "metrics",
#         "title": "Metrics",
#         "description": "Collects all available metrics.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "type": "debugdata",
#           "items": [
#             {
#               "observedFirstContentfulPaint": 200,
#               "observedNavigationStartTs": 189401285558,
#               "observedFirstVisualChangeTs": 189401489558,
#               "observedTimeOrigin": 0,
#               "firstContentfulPaint": 1357,
#               "observedFirstVisualChange": 204,
#               "observedFirstPaint": 200,
#               "observedFirstContentfulPaintTs": 189401485423,
#               "largestContentfulPaint": 1710,
#               "totalBlockingTime": 476,
#               "firstCPUIdle": 4279,
#               "observedFirstPaintTs": 189401485423,
#               "observedLoadTs": 189401658968,
#               "observedNavigationStart": 0,
#               "observedDomContentLoaded": 185,
#               "observedTimeOriginTs": 189401285558,
#               "observedLargestContentfulPaintTs": 189401485423,
#               "interactive": 4699,
#               "observedSpeedIndexTs": 189401490303,
#               "observedCumulativeLayoutShift": 0,
#               "estimatedInputLatency": 65,
#               "observedFirstMeaningfulPaintTs": 189401485423,
#               "observedLastVisualChangeTs": 189401489558,
#               "observedFirstMeaningfulPaint": 200,
#               "firstMeaningfulPaint": 1357,
#               "observedTraceEndTs": 189402787850,
#               "observedSpeedIndex": 205,
#               "cumulativeLayoutShift": 0,
#               "observedLoad": 373,
#               "observedLastVisualChange": 204,
#               "observedLargestContentfulPaint": 200,
#               "speedIndex": 1357,
#               "maxPotentialFID": 327,
#               "observedDomContentLoadedTs": 189401470074,
#               "observedTraceEnd": 1502
#             },
#             {
#               "lcpInvalidated": false
#             }
#           ]
#         },
#         "numericValue": 4699
#       },
#       "uses-webp-images": {
#         "id": "uses-webp-images",
#         "title": "Serve images in next-gen formats",
#         "description": "Image formats like JPEG 2000, JPEG XR, and WebP often provide better compression than PNG or JPEG, which means faster downloads and less data consumption. [Learn more](https://web.dev/uses-webp-images/).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "type": "opportunity",
#           "headings": [],
#           "overallSavingsBytes": 0,
#           "overallSavingsMs": 0,
#           "items": []
#         },
#         "warnings": [],
#         "numericValue": 0
#       },
#       "uses-text-compression": {
#         "id": "uses-text-compression",
#         "title": "Enable text compression",
#         "description": "Text-based resources should be served with compression (gzip, deflate or brotli) to minimize total network bytes. [Learn more](https://web.dev/uses-text-compression/).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "type": "opportunity",
#           "items": [],
#           "overallSavingsMs": 0,
#           "headings": [],
#           "overallSavingsBytes": 0
#         },
#         "numericValue": 0
#       },
#       "max-potential-fid": {
#         "id": "max-potential-fid",
#         "title": "Max Potential First Input Delay",
#         "description": "The maximum potential First Input Delay that your users could experience is the duration of the longest task. [Learn more](https://web.dev/lighthouse-max-potential-fid/).",
#         "score": 0.3,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "330 ms",
#         "numericValue": 327
#       }
#     },
#     "categories": {
#       "performance": {
#         "id": "performance",
#         "title": "Performance",
#         "score": 0.88,
#         "auditRefs": [
#           {
#             "id": "first-contentful-paint",
#             "weight": 15,
#             "group": "metrics"
#           },
#           {
#             "id": "speed-index",
#             "weight": 15,
#             "group": "metrics"
#           },
#           {
#             "id": "largest-contentful-paint",
#             "weight": 25,
#             "group": "metrics"
#           },
#           {
#             "id": "interactive",
#             "weight": 15,
#             "group": "metrics"
#           },
#           {
#             "id": "total-blocking-time",
#             "weight": 25,
#             "group": "metrics"
#           },
#           {
#             "id": "cumulative-layout-shift",
#             "weight": 5,
#             "group": "metrics"
#           },
#           {
#             "id": "first-cpu-idle",
#             "weight": 0
#           },
#           {
#             "id": "max-potential-fid",
#             "weight": 0
#           },
#           {
#             "id": "first-meaningful-paint",
#             "weight": 0
#           },
#           {
#             "id": "estimated-input-latency",
#             "weight": 0
#           },
#           {
#             "id": "render-blocking-resources",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-responsive-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "offscreen-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "unminified-css",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "unminified-javascript",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "unused-css-rules",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "unused-javascript",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-optimized-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-webp-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-text-compression",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-rel-preconnect",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "server-response-time",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "redirects",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-rel-preload",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "efficient-animated-content",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "duplicated-javascript",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "legacy-javascript",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "total-byte-weight",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "uses-long-cache-ttl",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "dom-size",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "critical-request-chains",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "user-timings",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "bootup-time",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "mainthread-work-breakdown",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "font-display",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "performance-budget",
#             "weight": 0,
#             "group": "budgets"
#           },
#           {
#             "id": "timing-budget",
#             "weight": 0,
#             "group": "budgets"
#           },
#           {
#             "id": "resource-summary",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "third-party-summary",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "largest-contentful-paint-element",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "layout-shift-elements",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "uses-passive-event-listeners",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "no-document-write",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "long-tasks",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "non-composited-animations",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "large-javascript-libraries",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "network-requests",
#             "weight": 0
#           },
#           {
#             "id": "network-rtt",
#             "weight": 0
#           },
#           {
#             "id": "network-server-latency",
#             "weight": 0
#           },
#           {
#             "id": "main-thread-tasks",
#             "weight": 0
#           },
#           {
#             "id": "diagnostics",
#             "weight": 0
#           },
#           {
#             "id": "metrics",
#             "weight": 0
#           },
#           {
#             "id": "screenshot-thumbnails",
#             "weight": 0
#           },
#           {
#             "id": "final-screenshot",
#             "weight": 0
#           },
#           {
#             "id": "first-contentful-paint-3g",
#             "weight": 0
#           }
#         ]
#       }
#     },
#     "categoryGroups": {
#       "a11y-best-practices": {
#         "title": "Best practices",
#         "description": "These items highlight common accessibility best practices."
#       },
#       "load-opportunities": {
#         "title": "Opportunities",
#         "description": "These suggestions can help your page load faster. They don't [directly affect](https://web.dev/performance-scoring/) the Performance score."
#       },
#       "seo-crawl": {
#         "title": "Crawling and Indexing",
#         "description": "To appear in search results, crawlers need access to your app."
#       },
#       "a11y-tables-lists": {
#         "title": "Tables and lists",
#         "description": "These are opportunities to improve the experience of reading tabular or list data using assistive technology, like a screen reader."
#       },
#       "metrics": {
#         "title": "Metrics"
#       },
#       "a11y-color-contrast": {
#         "title": "Contrast",
#         "description": "These are opportunities to improve the legibility of your content."
#       },
#       "a11y-names-labels": {
#         "title": "Names and labels",
#         "description": "These are opportunities to improve the semantics of the controls in your application. This may enhance the experience for users of assistive technology, like a screen reader."
#       },
#       "a11y-language": {
#         "title": "Internationalization and localization",
#         "description": "These are opportunities to improve the interpretation of your content by users in different locales."
#       },
#       "diagnostics": {
#         "title": "Diagnostics",
#         "description": "More information about the performance of your application. These numbers don't [directly affect](https://web.dev/performance-scoring/) the Performance score."
#       },
#       "best-practices-browser-compat": {
#         "title": "Browser Compatibility"
#       },
#       "budgets": {
#         "title": "Budgets",
#         "description": "Performance budgets set standards for the performance of your site."
#       },
#       "pwa-installable": {
#         "title": "Installable"
#       },
#       "seo-mobile": {
#         "title": "Mobile Friendly",
#         "description": "Make sure your pages are mobile friendly so users don’t have to pinch or zoom in order to read the content pages. [Learn more](https://developers.google.com/search/mobile-sites/)."
#       },
#       "best-practices-general": {
#         "title": "General"
#       },
#       "a11y-navigation": {
#         "title": "Navigation",
#         "description": "These are opportunities to improve keyboard navigation in your application."
#       },
#       "seo-content": {
#         "title": "Content Best Practices",
#         "description": "Format your HTML in a way that enables crawlers to better understand your app’s content."
#       },
#       "best-practices-trust-safety": {
#         "title": "Trust and Safety"
#       },
#       "best-practices-ux": {
#         "title": "User Experience"
#       },
#       "a11y-audio-video": {
#         "title": "Audio and video",
#         "description": "These are opportunities to provide alternative content for audio and video. This may improve the experience for users with hearing or vision impairments."
#       },
#       "a11y-aria": {
#         "title": "ARIA",
#         "description": "These are opportunities to improve the usage of ARIA in your application which may enhance the experience for users of assistive technology, like a screen reader."
#       },
#       "pwa-optimized": {
#         "title": "PWA Optimized"
#       },
#       "pwa-fast-reliable": {
#         "title": "Fast and reliable"
#       }
#     },
#     "timing": {
#       "total": 4253.61
#     },
#     "i18n": {
#       "rendererFormattedStrings": {
#         "varianceDisclaimer": "Values are estimated and may vary. The [performance score is calculated](https://web.dev/performance-scoring/) directly from these metrics.",
#         "opportunityResourceColumnLabel": "Opportunity",
#         "opportunitySavingsColumnLabel": "Estimated Savings",
#         "errorMissingAuditInfo": "Report error: no audit information",
#         "errorLabel": "Error!",
#         "warningHeader": "Warnings: ",
#         "auditGroupExpandTooltip": "Show audits",
#         "passedAuditsGroupTitle": "Passed audits",
#         "notApplicableAuditsGroupTitle": "Not applicable",
#         "manualAuditsGroupTitle": "Additional items to manually check",
#         "toplevelWarningsMessage": "There were issues affecting this run of Lighthouse:",
#         "crcLongestDurationLabel": "Maximum critical path latency:",
#         "crcInitialNavigation": "Initial Navigation",
#         "lsPerformanceCategoryDescription": "[Lighthouse](https://developers.google.com/web/tools/lighthouse/) analysis of the current page on an emulated mobile network. Values are estimated and may vary.",
#         "labDataTitle": "Lab Data"
#       }
#     }
#   },
#   "analysisUTCTimestamp": "2020-11-05T14:49:38.839Z"
# }

# %%
# Convert to json format
result_json = json.loads(result)

print(result_json)

with open('result.json', 'w') as outfile:
  json.dump(result_json, outfile)

files.download('result.json')
# Out:
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.asos.com/women//', 'loadingExperience': {'id': 'https://www.asos.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 1350, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.5752680600899103}, {'min': 1000, 'max': 3000, 'proportion': 0.3816813446415494}, {'min': 3000, 'proportion': 0.04305059526854033}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 58, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8203198428939458}, {'min': 100, 'max': 300, 'proportion': 0.11387123095123568}, {'min': 300, 'proportion': 0.0658089261548186}], 'category': 'FAST'}, 'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 21, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.6645479460426003}, {'min': 10, 'max': 25, 'proportion': 0.1227956254331982}, {'min': 25, 'proportion': 0.21265642852420152}], 'category': 'AVERAGE'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 2969, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.6770998771326743}, {'min': 2500, 'max': 4000, 'proportion': 0.17111819040206233}, {'min': 4000, 'proportion': 0.15178193246526336}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.asos.com/women//', 'origin_fallback': True}, 'originLoadingExperience': {'id': 'https://www.asos.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 1350, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.5752680600899103}, {'min': 1000, 'max': 3000, 'proportion': 0.3816813446415494}, {'min': 3000, 'proportion': 0.04305059526854033}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 58, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8203198428939458}, {'min': 100, 'max': 300, 'proportion': 0.11387123095123568}, {'min': 300, 'proportion': 0.0658089261548186}], 'category': 'FAST'}, 'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 21, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.6645479460426003}, {'min': 10, 'max': 25, 'proportion': 0.1227956254331982}, {'min': 25, 'proportion': 0.21265642852420152}], 'category': 'AVERAGE'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 2969, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.6770998771326743}, {'min': 2500, 'max': 4000, 'proportion': 0.17111819040206233}, {'min': 4000, 'proportion': 0.15178193246526336}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.asos.com/women//'}, 'lighthouseResult': {'requestedUrl': 'https://www.asos.com/women//', 'finalUrl': 'https://www.asos.com/women//', 'lighthouseVersion': '6.3.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/84.0.4147.140 Safari/537.36', 'fetchTime': '2020-11-02T15:43:50.735Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 7.0; Moto G (4)) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4143.7 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/84.0.4147.140 Safari/537.36', 'benchmarkIndex': 841}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'resource-summary': {'id': 'resource-summary', 'title': 'Keep request counts low and transfer sizes small', 'description': 'To set budgets for the quantity and size of page resources, add a budget.json file. [Learn more](https://web.dev/use-lighthouse-for-performance-budgets/).', 'score': None, 'scoreDisplayMode': 'informative', 'displayValue': '158 requests • 2,092 KiB', 'details': {'headings': [{'itemType': 'text', 'text': 'Resource Type', 'key': 'label'}, {'itemType': 'numeric', 'text': 'Requests', 'key': 'requestCount'}, {'key': 'transferSize', 'text': 'Transfer Size', 'itemType': 'bytes'}], 'type': 'table', 'items': [{'transferSize': 2142679, 'requestCount': 158, 'label': ...

# %%
uploaded = files.upload()
#if your column header is something other than 'url' please define it here 
column_header='url'
# Out:
#      <input type="file" id="files-e4584ee2-1261-4ae0-ab76-5aca21e308d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4584ee2-1261-4ae0-ab76-5aca21e308d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving result (1).json to result (1) (1).json

# %%
# Get the filename from the upload so we can read it into a CSV.
for key in uploaded.keys():
  filename = key
# Read the selected file into a Pandas Dataframe
df = pd.read_csv(io.BytesIO(uploaded[filename]))

df.head()
# Out:
# Empty DataFrame
# Columns: [{"captchaResult": "CAPTCHA_NOT_NEEDED",  "kind": "pagespeedonline#result",  "id": "https://www.asos.com/women//",  "loadingExperience": {"id": "https://www.asos.com",  "metrics": {"FIRST_CONTENTFUL_PAINT_MS": {"percentile": 1350,  "distributions": [{"min": 0,  "max": 1000,  "proportion": 0.5752680600899103},  {"min": 1000,  "max": 3000,  "proportion": 0.3816813446415494},  {"min": 3000,  "proportion": 0.04305059526854033}],  "category": "AVERAGE"},  "FIRST_INPUT_DELAY_MS": {"percentile": 58,  "distributions": [{"min": 0.1,  "max": 100,  "proportion": 0.8203198428939458},  {"min": 100,  "max": 300,  "proportion": 0.11387123095123568},  {"min": 300,  "proportion": 0.0658089261548186}],  "category": "FAST"},  "CUMULATIVE_LAYOUT_SHIFT_SCORE": {"percentile": 21,  "distributions": [{"min": 0.2,  "max": 10,  "proportion": 0.6645479460426003},  {"min": 10,  "max": 25,  "proportion": 0.1227956254331982},  {"min": 25,  "proportion": 0.21265642852420152}],  "category": "AVERAGE"}.1,  "LARGEST_CONTENTFUL_PAINT_MS": {"percentile": 2969,  "distributions": [{"min": 0.3,  "max": 2500,  "proportion": 0.6770998771326743},  {"min": 2500,  "max": 4000,  "proportion": 0.17111819040206233},  {"min": 4000,  "proportion": 0.15178193246526336}],  "category": "AVERAGE"}},  "overall_category": "AVERAGE",  "initial_url": "https://www.asos.com/women//",  "origin_fallback": true},  "originLoadingExperience": {"id": "https://www.asos.com",  "metrics": {"FIRST_CONTENTFUL_PAINT_MS": {"percentile": 1350.1,  "distributions": [{"min": 0.4,  "max": 1000.1,  "proportion": 0.5752680600899103}.1,  {"min": 1000.1,  "max": 3000.1,  "proportion": 0.3816813446415494}.1,  {"min": 3000.1,  "proportion": 0.04305059526854033}].1,  "category": "AVERAGE"}.2,  "FIRST_INPUT_DELAY_MS": {"percentile": 58.1,  "distributions": [{"min": 0.5,  "max": 100.1,  "proportion": 0.8203198428939458}.1,  {"min": 100.1,  "max": 300.1,  "proportion": 0.11387123095123568}.1,  {"min": 300.1,  "proportion": 0.0658089261548186}].1,  "category": "FAST"}.1,  "CUMULATIVE_LAYOUT_SHIFT_SCORE": {"percentile": 21.1,  "distributions": [{"min": 0.6,  "max": 10.1,  "proportion": 0.6645479460426003}.1,  {"min": 10.1,  "max": 25.1,  "proportion": 0.1227956254331982}.1,  {"min": 25.1,  "proportion": 0.21265642852420152}].1,  "category": "AVERAGE"}.3,  "LARGEST_CONTENTFUL_PAINT_MS": {"percentile": 2969.1,  "distributions": [{"min": 0.7,  "max": 2500.1,  "proportion": 0.6770998771326743}.1,  {"min": 2500.1,  "max": 4000.1,  "proportion": 0.17111819040206233}.1,  {"min": 4000.1,  "proportion": 0.15178193246526336}].1,  "category": "AVERAGE"}}.1,  "overall_category": "AVERAGE".1,  "initial_url": "https://www.asos.com/women//"},  "lighthouseResult": {"requestedUrl": "https://www.asos.com/women//",  "finalUrl": "https://www.asos.com/women//",  "lighthouseVersion": "6.3.0",  "userAgent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML,  like Gecko) HeadlessChrome/84.0.4147.140 Safari/537.36",  "fetchTime": "2020-11-02T15:43:50.735Z",  "environment": {"networkUserAgent": "Mozilla/5.0 (Linux; Android 7.0; Moto G (4)) AppleWebKit/537.36 (KHTML,  like Gecko) Chrome/84.0.4143.7 Mobile Safari/537.36 Chrome-Lighthouse",  "hostUserAgent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML,  like Gecko) HeadlessChrome/84.0.4147.140 Safari/537.36".1, ...]
# Index: []
#
# [0 rows x 4978 columns]

# %%
response_object = {}

# Iterate through the df
for x in range(0, len(df)):

        # Define request parameter
        url = df.iloc[x][column_header]

        # Make request
        pagespeed_results = urllib.request.urlopen('https://www.googleapis.com/pagespeedonline/v5/runPagespeed?url={}&strategy=mobile'.format(url)).read().decode('UTF-8')

        # Convert to json format
        pagespeed_results_json = json.loads(pagespeed_results)

        # Insert returned json response into response_object
        response_object[url] = pagespeed_results_json
        time.sleep(30)
        
        print(response_object[url])

# %%
# Create dataframe to store responses
df_pagespeed_results = pd.DataFrame(columns=
          ['url',
          'Overall_Category',
          'Largest_Contentful_Paint',
          'First_Input_Delay',
          'Cumulative_Layout_Shift',
          'First_Contentful_Paint',
          'Time_to_Interactive',
          'Total_Blocking_Time',
          'Speed_Index'])  

print(df_pagespeed_results)
# Out:
# Empty DataFrame
# Columns: [url, Overall_Category, Largest_Contentful_Paint, First_Input_Delay, Cumulative_Layout_Shift, First_Contentful_Paint, Time_to_Interactive, Total_Blocking_Time, Speed_Index]
# Index: []

# %%
for (url, x) in zip(
    response_object.keys(),
    range(0, len(response_object))
):

        # URLs
        df_pagespeed_results.loc[x, 'url'] =\
            response_object[url]['lighthouseResult']['finalUrl']

        # Overall Category
        df_pagespeed_results.loc[x, 'Overall_Category'] =\
            response_object[url]['loadingExperience']['overall_category']   

        # Core Web Vitals     

        # Largest Contentful Paint    
        df_pagespeed_results.loc[x, 'Largest_Contentful_Paint'] =\
        response_object[url]['lighthouseResult']['audits']['largest-contentful-paint']['displayValue']

        # First Input Delay 
        fid = response_object[url]['loadingExperience']['metrics']['FIRST_INPUT_DELAY_MS']
        df_pagespeed_results.loc[x, 'First_Input_Delay'] = fid['percentile']

        # Cumulative Layout Shift    
        df_pagespeed_results.loc[x, 'Cumulative_Layout_Shift'] =\
        response_object[url]['lighthouseResult']['audits']['cumulative-layout-shift']['displayValue']

        # Additional Loading Metrics 

        # First Contentful Paint 
        df_pagespeed_results.loc[x, 'First_Contentful_Paint'] =\
        response_object[url]['lighthouseResult']['audits']['first-contentful-paint']['displayValue']

        # Additional Interactivity Metrics 

        # Time to Interactive  
        df_pagespeed_results.loc[x, 'Time_to_Interactive'] =\
        response_object[url]['lighthouseResult']['audits']['interactive']['displayValue']

        # Total Blocking Time   
        df_pagespeed_results.loc[x, 'Total_Blocking_Time'] =\
        response_object[url]['lighthouseResult']['audits']['total-blocking-time']['displayValue']

        # Speed Index
        df_pagespeed_results.loc[x, 'Speed_Index'] =\
        response_object[url]['lighthouseResult']['audits']['speed-index']['displayValue']

# %%
summary = df_pagespeed_results

df_pagespeed_results.head()

#Download csv file 
summary.to_csv('pagespeed_results.csv')
files.download('pagespeed_results.csv')

# %%
#Replace the 's' with a blank space so we can turn into numbers
df_pagespeed_results['Largest_Contentful_Paint'] = df_pagespeed_results.Largest_Contentful_Paint.str.replace('s', '')
df_pagespeed_results['First_Contentful_Paint'] = df_pagespeed_results.First_Contentful_Paint.str.replace('s', '')
df_pagespeed_results['Time_to_Interactive'] = df_pagespeed_results.Time_to_Interactive.str.replace('s', '')
df_pagespeed_results['Total_Blocking_Time'] = df_pagespeed_results.Total_Blocking_Time.str.replace('ms', '')
df_pagespeed_results['Speed_Index'] = df_pagespeed_results.Speed_Index.str.replace('s', '')

# %%
#Turn strings into intergers or floats
df_pagespeed_results['Largest_Contentful_Paint'] = df_pagespeed_results.Largest_Contentful_Paint.astype(float)
df_pagespeed_results['Cumulative_Layout_Shift'] = df_pagespeed_results.Cumulative_Layout_Shift.astype(int)
df_pagespeed_results['First_Contentful_Paint'] = df_pagespeed_results.First_Contentful_Paint.astype(float)
df_pagespeed_results['Time_to_Interactive'] = df_pagespeed_results.Time_to_Interactive.astype(float)
df_pagespeed_results['Speed_Index'] = df_pagespeed_results.Speed_Index.astype(float)
